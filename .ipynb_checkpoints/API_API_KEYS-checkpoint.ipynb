# %%
### 1st API

# %%
import requests
import json

response = requests.get('https://api.spaceflightnewsapi.net/v3/articles')

response.json()

results = response.json()
results
# Out:
# [{'id': 16813,
#   'title': 'Space companies face difficult investment environment',
#   'url': 'https://spacenews.com/space-companies-face-difficult-investment-environment/',
#   'imageUrl': 'https://spacenews.com/wp-content/uploads/2022/09/im1lander-2022.jpg',
#   'newsSite': 'SpaceNews',
#   'summary': 'Rising interest rates are making it more difficult for space startups to raise money, some warn, forcing them to seek alternative sources of funding.',
#   'publishedAt': '2022-10-11T12:10:25.000Z',
#   'updatedAt': '2022-10-11T12:10:25.238Z',
#   'featured': False,
#   'launches': [],
#   'events': []},
#  {'id': 16809,
#   'title': 'SpaceX deploys two of six C-band satellites Intelsat is launching this year',
#   'url': 'https://spacenews.com/spacex-deploys-two-of-six-c-band-satellites-intelsat-is-launching-this-year/',
#   'imageUrl': 'https://spacenews.com/wp-content/uploads/2022/10/hereSpaceX-intelsat-launch.jpeg',
#   'newsSite': 'SpaceNews',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
print(data.shape)
data.head(10)
# Out:
# (10, 11)
#       id                                              title  \
# 0  16813  Space companies face difficult investment envi...
# 1  16809  SpaceX deploys two of six C-band satellites In...
# 2  16808  Former SES CEO joins megaconstellation startup...
# 3  16807  Launch on demand: If satellites are shot down,...
# 4  16812  United Launch Alliance's debut Vulcan mission ...
# 5  16806  Stoke Space aims to build rapidly reusable roc...
# 6  16805  Firefly says Alpha launch a success despite pa...
# 7  16811  SpaceX’s first Falcon Heavy launch in three ye...
# 8  16810                    Starlink now available in Japan
# 9  16803  Researchers discover galactic shield of gas su...
#
#                                                  url  \
# 0  https://spacenews.com/space-companies-face-dif...
# 1  https://spacenews.com/spacex-deploys-two-of-si...
# 2  https://spacenews.com/former-ses-ceo-joins-meg...
# 3  https://spacenews.com/launch-on-demand-if-sate...
# ...

# %%
from pandas.io.json import json_normalize

flattened_data = json_normalize(results)
print(flattened_data.shape)
flattened_data
# Out:
# (10, 11)
# /var/folders/r5/f_ppj8yd0_bfvgt7j7sddzzh0000gn/T/ipykernel_1268/2480666601.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results)
#       id                                              title  \
# 0  16813  Space companies face difficult investment envi...
# 1  16809  SpaceX deploys two of six C-band satellites In...
# 2  16808  Former SES CEO joins megaconstellation startup...
# 3  16807  Launch on demand: If satellites are shot down,...
# 4  16812  United Launch Alliance's debut Vulcan mission ...
# 5  16806  Stoke Space aims to build rapidly reusable roc...
# 6  16805  Firefly says Alpha launch a success despite pa...
# 7  16811  SpaceX’s first Falcon Heavy launch in three ye...
# 8  16810                    Starlink now available in Japan
# 9  16803  Researchers discover galactic shield of gas su...
#
#                                                  url  \
# ...

# %%
### 2 API

# %%
import requests
import json

response1 = requests.get('https://quote-garden.herokuapp.com/api/v3/quotes')

response1
results1 = response1.json()
#print(results1)
results1['data'] # when i print the results1 it gives the actual responses are available only in the data key of the response object so i just picked the data.
# Out:
# [{'_id': '5eb17aadb69dc744b4e70d2e',
#   'quoteText': 'All diseases run into one, old age.',
#   'quoteAuthor': 'Ralph Waldo Emerson',
#   'quoteGenre': 'age',
#   '__v': 0},
#  {'_id': '5eb17aadb69dc744b4e70d36',
#   'quoteText': 'Alas, after a certain age every man is responsible for his face.',
#   'quoteAuthor': 'Albert Camus',
#   'quoteGenre': 'age',
#   '__v': 0},
#  {'_id': '5eb17aadb69dc744b4e70d44',
#   'quoteText': 'When grace is joined with wrinkles, it is adorable. There is an unspeakable dawn in happy old age.',
#   'quoteAuthor': 'Victor Hugo',
#   'quoteGenre': 'age',
#   '__v': 0},
#  {'_id': '5eb17aadb69dc744b4e70d48',
#   'quoteText': 'Age is not a particularly interesting subject. Anyone can get old. All you have to do is live long enough.',
#   'quoteAuthor': 'Don Marquis',
#   'quoteGenre': 'age',
#   '__v': 0},
#  {'_id': '5eb17aadb69dc744b4e70d5e',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data1 = pd.DataFrame(results1['data'])
print(data1.shape)
data1.head(10)
# Out:
# (10, 5)
#                         _id  \
# 0  5eb17aadb69dc744b4e70d2e
# 1  5eb17aadb69dc744b4e70d36
# 2  5eb17aadb69dc744b4e70d44
# 3  5eb17aadb69dc744b4e70d48
# 4  5eb17aadb69dc744b4e70d5e
# 5  5eb17aadb69dc744b4e70d65
# 6  5eb17aadb69dc744b4e70d6b
# 7  5eb17aadb69dc744b4e70d78
# 8  5eb17aadb69dc744b4e70d7d
# 9  5eb17aadb69dc744b4e70d86
#
#                                            quoteText              quoteAuthor  \
# 0                All diseases run into one, old age.      Ralph Waldo Emerson
# 1  Alas, after a certain age every man is respons...             Albert Camus
# 2  When grace is joined with wrinkles, it is ador...              Victor Hugo
# 3  Age is not a particularly interesting subject....              Don Marquis
# 4  My notion of a wife at 40 is that a man should...            Warren Beatty
# 5  Aging seems to be the only available way to li...    Kitty O'Neill Collins
# 6  You know you're getting old when all the names...            Harrison Ford
# ...

# %%
from pandas.io.json import json_normalize

flattened_data1 = json_normalize(results1['data'])
print(flattened_data1.shape)
flattened_data1
# Out:
# (10, 5)
# /var/folders/r5/f_ppj8yd0_bfvgt7j7sddzzh0000gn/T/ipykernel_1268/1909536014.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data1 = json_normalize(results1['data'])
#                         _id  \
# 0  5eb17aadb69dc744b4e70d2e
# 1  5eb17aadb69dc744b4e70d36
# 2  5eb17aadb69dc744b4e70d44
# 3  5eb17aadb69dc744b4e70d48
# 4  5eb17aadb69dc744b4e70d5e
# 5  5eb17aadb69dc744b4e70d65
# 6  5eb17aadb69dc744b4e70d6b
# 7  5eb17aadb69dc744b4e70d78
# 8  5eb17aadb69dc744b4e70d7d
# 9  5eb17aadb69dc744b4e70d86
#
#                                            quoteText              quoteAuthor  \
# 0                All diseases run into one, old age.      Ralph Waldo Emerson
# 1  Alas, after a certain age every man is respons...             Albert Camus
# 2  When grace is joined with wrinkles, it is ador...              Victor Hugo
# 3  Age is not a particularly interesting subject....              Don Marquis
# ...

# %%
### 3. API tried with the keys

# %%
import getpass
apikey = getpass.getpass()
# Out:
# ········

# %%
response2 = requests.get('https://phonevalidation.abstractapi.com/v1?api_key=' + apikey + '&phone=31626317687')  
    

#response
results2 = response2.json()
results2
# Out:
# {'phone': '31626317687',
#  'valid': True,
#  'format': {'international': '+31626317687', 'local': '06 26317687'},
#  'country': {'code': 'NL', 'name': 'Netherlands', 'prefix': '+31'},
#  'location': 'Netherlands',
#  'type': 'mobile',
#  'carrier': 'Telfort'}

# %%
print(results2['country']['name'])
# Out:
# Netherlands
